# %%
import pandas as pd
import missingno as msno

# %load_ext autoreload
# %autoreload 2

path_processed = '/home/matteo@COPPET/Documents/data_science/projects/housing_prices_firenze/data/processed/'

# %% [markdown]
# # Missing data

# %% [markdown]
# ## 1. Loading data

# %%
df = pd.read_csv(path_processed+'data_clean.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7780 entries, 0 to 7779
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Superficie                   7780 non-null   float64
#  1   Piano                        7658 non-null   object
#  2   Zona                         7780 non-null   object
#  3   Prezzo                       7780 non-null   float64
#  4   Stato                        7576 non-null   object
#  5   Climatizzazione              7780 non-null   object
#  6   Prezzo_per_m2                7780 non-null   float64
#  7   Classe_immobile              6718 non-null   object
#  8   Tipo_proprietà               7392 non-null   object
#  9   Tipologia_casa               7780 non-null   object
#  10  Anno_costruzione_bins        5673 non-null   object
#  11  Riscaldamento_A_C            7780 non-null   object
#  12  Tipo_riscaldamento           6054 non-null   object
# ...

# %% [markdown]
# ## 2. Visualizing missing data

# %%
df_missingdata = df.columns[df.isna().any()].tolist()

# %% [markdown]
# ### 2.1 Matrix visualization

# %%
msno.matrix(df[df_missingdata])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 2.2 Barchart visualization

# %%
msno.bar(df[df_missingdata], color="blue", log=True, figsize=(30,18))
# Out:
# /home/matteo@COPPET/anaconda3/envs/housing_prices_firenze/lib/python3.8/site-packages/missingno/missingno.py:257: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_yticklabels([int(n*len(df)) for n in ax1.get_yticks()], fontsize=fontsize)
# <AxesSubplot:>

# %% [markdown]
# ### 2.3 Heatmap visualization

# %%
msno.heatmap(df[df_missingdata], figsize=(20,20))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 2.4 Dendogram visualization

# %%
msno.dendrogram(df[df_missingdata])
# Out:
# <AxesSubplot:>
